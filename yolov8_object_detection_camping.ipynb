# %% [markdown]
# # 환경설정

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/new_AR/camping
# Out:
# /content/drive/MyDrive/new_AR/camping

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 595.4/595.4 kB 27.7 MB/s eta 0:00:00
# ...

# %%
# !pip install -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
import torch
from IPython.display import Image  # for displaying images
import xml.etree.ElementTree as ET
from xml.dom import minidom
from tqdm import tqdm
from PIL import Image, ImageDraw
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # 학습 시작

# %%
from ultralytics import YOLO
model = YOLO("yolov8s.pt")

# %%
model.train(data="data_camping.yaml", patience=15, batch=16, cache=True, epochs=300)
# Out:
# Ultralytics YOLOv8.0.105 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO
model = YOLO("camping/runs/detect/train5/weights/last.pt")
#model.train(resume=True)

# %%
import tensorflow as tf
import datetime, os

# %%
from tensorboard import notebook
notebook.list()
# Out:
# Known TensorBoard instances:
#   - port 6006: logdir /content/drive/MyDrive/Activity_Recognition/art/runs/detect/train (started 0:08:41 ago; pid 2394)

# %%
#학습 완료된 후에 tensorboard 통해 로그 확인
# %load_ext tensorboard
# %tensorboard --logdir /content/drive/MyDrive/new_AR/art/runs/detect/train6
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
metrics = model.val()
# Out:
# Ultralytics YOLOv8.0.114 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
# 100%|██████████| 755k/755k [00:00<00:00, 79.3MB/s]
# val: Scanning /content/drive/MyDrive/new_AR/camping/datasets/labels/val... 1660 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1660/1660 [04:05<00:00,  6.77it/s]
# val: New cache created: /content/drive/MyDrive/new_AR/camping/datasets/labels/val.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 104/104 [01:03<00:00,  1.63it/s]
#                    all       1660       1756      0.866      0.888      0.916       0.74
#              Water Jug       1660        163      0.844      0.894      0.927      0.762
#             an ice box       1660        134      0.994          1      0.995      0.944
#                 Coppel       1660        187      0.803       0.84      0.864      0.686
#   a portable gas stove       1660        185      0.985      0.978      0.995      0.851
# ...

# %% [markdown]
# 검증하기

# %%
# !python val.py --data /content/drive/MyDrive/new_AR/camping/data_camping.yaml --img 640 --weights /content/drive/MyDrive/new_AR/camping/runs/detect/train6/results/weights/best.pt
# Out:
# python3: can't open file '/content/drive/MyDrive/new_AR/val.py': [Errno 2] No such file or directory

# %% [markdown]
# 예측하기

# %%
# !python detect.py --weights /content/drive/MyDrive/Activity_Recognition/yolov5/runs/train/results/weights/best.pt --img 1280 --conf 0.5 --source /content/drive/MyDrive/Activity_Recognition/test_img.jpg
